# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Math and Portuguese data
math_df = pd.read_csv("data/student-mat.csv", sep=';')
port_df = pd.read_csv("data/student-por.csv", sep=';')


math_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
port_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
port_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
math_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
# Combine the data
student_data_df = pd.concat([math_df,port_df])
student_data_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %%
# Check for any missing values
student_data_df.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
# Rename columns
student_data_df.columns = ['school','sex','age','address','family_size','parents_status','mother_education','father_education',
           'mother_job','father_job','reason','guardian','travel_time','study_time','failures','school_support',
          'family_support','paid_classes','extra_activities','nursery_school','wants_higher_edu','internet','romantic','family_relation',
          'free_time','go_out','weekday_alcohol','weekend_alcohol','health','absences','Q1_score','Q2_score','final_score']

# %%
# Create final grade column for letter grades A+:18-20 A:16-17 B:14-15 C:10-13 & F<10 
student_data_df['final_letter_grade'] = 'None'
student_data_df.loc[(student_data_df.final_score >= 18) & (student_data_df.final_score <= 20), 'final_letter_grade'] = 'A+' 
student_data_df.loc[(student_data_df.final_score >= 16) & (student_data_df.final_score <= 17), 'final_letter_grade'] = 'A'
student_data_df.loc[(student_data_df.final_score >= 14) & (student_data_df.final_score <= 15), 'final_letter_grade'] = 'B' 
student_data_df.loc[(student_data_df.final_score >= 10) & (student_data_df.final_score <= 13), 'final_letter_grade'] = 'C' 
student_data_df.loc[(student_data_df.final_score >= 0) & (student_data_df.final_score <= 10), 'final_letter_grade'] = 'F' 
student_data_df
# Out:
#     school sex  age address family_size parents_status  mother_education  \
# 0       GP   F   18       U         GT3              A                 4
# 1       GP   F   17       U         GT3              T                 1
# 2       GP   F   15       U         LE3              T                 1
# 3       GP   F   15       U         GT3              T                 4
# 4       GP   F   16       U         GT3              T                 3
# ..     ...  ..  ...     ...         ...            ...               ...
# 644     MS   F   19       R         GT3              T                 2
# 645     MS   F   18       U         LE3              T                 3
# 646     MS   F   18       U         GT3              T                 1
# 647     MS   M   17       U         LE3              T                 3
# 648     MS   M   18       R         LE3              T                 3
#
#      father_education mother_job father_job  ... free_time go_out  \
# 0                   4    at_home    teacher  ...         3      4
# 1                   1    at_home      other  ...         3      3
# 2                   1    at_home      other  ...         3      2
# 3                   2     health   services  ...         2      2
# 4                   3      other      other  ...         3      2
# ..                ...        ...        ...  ...       ...    ...
# 644                 3   services      other  ...         4      2
# 645                 1    teacher   services  ...         3      4
# 646                 1      other      other  ...         1      1
# 647                 1   services   services  ...         4      5
# 648                 2   services      other  ...         4      1
#
#      weekday_alcohol  weekend_alcohol  health absences Q1_score Q2_score  \
# 0                  1                1       3        6        5        6
# 1                  1                1       3        4        5        5
# 2                  2                3       3       10        7        8
# 3                  1                1       5        2       15       14
# 4                  1                2       5        4        6       10
# ..               ...              ...     ...      ...      ...      ...
# 644                1                2       5        4       10       11
# 645                1                1       1        4       15       15
# 646                1                1       5        6       11       12
# 647                3                4       2        6       10       10
# 648                3                4       5        4       10       11
#
#     final_score final_letter_grade
# 0             6                  F
# 1             6                  F
# 2            10                  F
# 3            15                  B
# 4            10                  F
# ..          ...                ...
# 644          10                  F
# 645          16                  A
# 646           9                  F
# 647          10                  F
# 648          11                  C
#
# [1044 rows x 34 columns]

# %%
#Check for null
student_data_df.isnull().values.any()
# Out:
# False

# %%
#Classification -Imports and Data Preprocessing

from sklearn import tree
from sklearn.preprocessing import LabelEncoder

#Classification_df= student_data_df.drop([ 'final_score','Q1_score','Q2_score'], axis=1)

Classification_df= student_data_df.drop(['final_score'], axis=1)
label = LabelEncoder()
Classification_df.final_letter_grade = label.fit_transform(Classification_df.final_letter_grade)
Classification_df
# Out:
#     school sex  age address family_size parents_status  mother_education  \
# 0       GP   F   18       U         GT3              A                 4
# 1       GP   F   17       U         GT3              T                 1
# 2       GP   F   15       U         LE3              T                 1
# 3       GP   F   15       U         GT3              T                 4
# 4       GP   F   16       U         GT3              T                 3
# ..     ...  ..  ...     ...         ...            ...               ...
# 644     MS   F   19       R         GT3              T                 2
# 645     MS   F   18       U         LE3              T                 3
# 646     MS   F   18       U         GT3              T                 1
# 647     MS   M   17       U         LE3              T                 3
# 648     MS   M   18       R         LE3              T                 3
#
#      father_education mother_job father_job  ... family_relation free_time  \
# 0                   4    at_home    teacher  ...               4         3
# 1                   1    at_home      other  ...               5         3
# 2                   1    at_home      other  ...               4         3
# 3                   2     health   services  ...               3         2
# 4                   3      other      other  ...               4         3
# ..                ...        ...        ...  ...             ...       ...
# 644                 3   services      other  ...               5         4
# 645                 1    teacher   services  ...               4         3
# 646                 1      other      other  ...               1         1
# 647                 1   services   services  ...               2         4
# 648                 2   services      other  ...               4         4
#
#      go_out  weekday_alcohol  weekend_alcohol health absences Q1_score  \
# 0         4                1                1      3        6        5
# 1         3                1                1      3        4        5
# 2         2                2                3      3       10        7
# 3         2                1                1      5        2       15
# 4         2                1                2      5        4        6
# ..      ...              ...              ...    ...      ...      ...
# 644       2                1                2      5        4       10
# 645       4                1                1      1        4       15
# 646       1                1                1      5        6       11
# 647       5                3                4      2        6       10
# 648       1                3                4      5        4       10
#
#     Q2_score final_letter_grade
# 0          6                  4
# 1          5                  4
# 2          8                  4
# 3         14                  2
# 4         10                  4
# ..       ...                ...
# 644       11                  4
# 645       15                  0
# 646       12                  4
# 647       10                  4
# 648       11                  3
#
# [1044 rows x 33 columns]

# %%
# label encode final_grade column
#label = preprocessing.LabelEncoder()
#Classification_df.final_letter_grade = label.fit_transform(Classification_df.final_letter_grade)
X = Classification_df.drop('final_letter_grade',axis=1)

y = Classification_df.final_letter_grade
print(X.shape, y.shape)
#train test split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=56)

len(list(X_train))
# Out:
# (1044, 32) (1044,)
# 32

# %%
#encode multiple columns using get_dummies
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
feature_names = X_train.columns
print(X_train.shape, X_test.shape)
# Out:
# (783, 58) (261, 58)

# %%
X_train.columns
# Out:
# Index(['age', 'mother_education', 'father_education', 'travel_time',
#        'study_time', 'failures', 'family_relation', 'free_time', 'go_out',
#        'weekday_alcohol', 'weekend_alcohol', 'health', 'absences', 'Q1_score',
#        'Q2_score', 'school_GP', 'school_MS', 'sex_F', 'sex_M', 'address_R',
#        'address_U', 'family_size_GT3', 'family_size_LE3', 'parents_status_A',
#        'parents_status_T', 'mother_job_at_home', 'mother_job_health',
#        'mother_job_other', 'mother_job_services', 'mother_job_teacher',
#        'father_job_at_home', 'father_job_health', 'father_job_other',
#        'father_job_services', 'father_job_teacher', 'reason_course',
#        'reason_home', 'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'school_support_no',
#        'school_support_yes', 'family_support_no', 'family_support_yes',
#        'paid_classes_no', 'paid_classes_yes', 'extra_activities_no',
#        'extra_activities_yes', 'nursery_school_no', 'nursery_school_yes',
#        'wants_higher_edu_no', 'wants_higher_edu_yes', 'internet_no',
#        'internet_yes', 'romantic_no', 'romantic_yes'],
#       dtype='object')

# %%
y_train
# Out:
# 365    0
# 59     0
# 88     4
# 370    4
# 267    2
#       ..
# 624    4
# 233    3
# 259    4
# 4      3
# 89     4
# Name: final_letter_grade, Length: 783, dtype: int32

# %%
#Model, Fit and get the score
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6934865900383141

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators=500)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7509578544061303

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators = 500))
sel.fit(X_train, y_train)
sel.get_support()

selected_feat= X_train.columns[(sel.get_support())]
len(selected_feat)

selected_feat
# Out:
# Index(['age', 'mother_education', 'father_education', 'study_time', 'failures',
#        'family_relation', 'free_time', 'go_out', 'weekend_alcohol', 'health',
#        'absences', 'Q1_score', 'Q2_score'],
#       dtype='object')

# %%
important_factors=sorted(zip(rf.feature_importances_, feature_names), reverse=True)
important_factors
# Out:
# [(0.2684689699655913, 'Q2_score'),
#  (0.17077175306786502, 'Q1_score'),
#  (0.036353305793917746, 'absences'),
#  (0.025376409666314, 'age'),
#  (0.024898733091589628, 'health'),
#  (0.02212907364673838, 'go_out'),
#  (0.021605329672477844, 'failures'),
#  (0.02125006511591837, 'father_education'),
#  (0.021215834929752014, 'free_time'),
#  (0.020766234483592327, 'mother_education'),
#  (0.01989471557721546, 'weekend_alcohol'),
#  (0.018806609234208876, 'study_time'),
#  (0.017297671601403185, 'family_relation'),
#  (0.012694172166377433, 'travel_time'),
#  (0.012172331343300917, 'weekday_alcohol'),
#  (0.009987699402011116, 'father_job_other'),
#  (0.009759032240011239, 'paid_classes_yes'),
#  (0.009746192767048663, 'paid_classes_no'),
#  (0.008542126041730116, 'family_support_no'),
#  (0.008445623313236124, 'reason_reputation'),
#  (0.008381509542795134, 'mother_job_other'),
#  (0.008367195206153276, 'family_support_yes'),
#  (0.008287863000594219, 'reason_course'),
#  (0.008119727592786627, 'father_job_services'),
#  (0.008117592574345406, 'extra_activities_yes'),
#  (0.008097320524403272, 'extra_activities_no'),
#  (0.008048556789673726, 'sex_F'),
#  (0.0076482101603188865, 'sex_M'),
#  (0.007579914738688315, 'guardian_mother'),
#  (0.0075064725726357055, 'romantic_yes'),
#  (0.007376844625987319, 'reason_home'),
#  (0.007352541980909676, 'school_MS'),
#  (0.007340526719465517, 'guardian_father'),
#  (0.007285785447391637, 'romantic_no'),
#  (0.007205423342597741, 'family_size_LE3'),
#  (0.00712367561053192, 'family_size_GT3'),
#  (0.006985924253578509, 'mother_job_services'),
#  (0.006385613711853075, 'school_GP'),
#  (0.006296954853042855, 'mother_job_at_home'),
#  (0.0061867122771951544, 'address_R'),
#  (0.006145826033365887, 'nursery_school_yes'),
#  (0.006094673759738245, 'address_U'),
#  (0.006091239677715917, 'mother_job_health'),
#  (0.006076364154754024, 'nursery_school_no'),
#  (0.005992974370223187, 'internet_yes'),
#  (0.005749930773895851, 'mother_job_teacher'),
#  (0.005707938175551142, 'internet_no'),
#  (0.00546399607390237, 'wants_higher_edu_yes'),
#  (0.005274007993358533, 'wants_higher_edu_no'),
#  (0.005154957801050849, 'school_support_no'),
#  (0.005089345956198857, 'school_support_yes'),
#  (0.004697159421458823, 'reason_other'),
#  (0.004569223812421137, 'parents_status_T'),
#  (0.004471979523092053, 'parents_status_A'),
#  (0.003938243278900504, 'father_job_at_home'),
#  (0.0033603016777936116, 'father_job_teacher'),
#  (0.0033511993184700832, 'guardian_other'),
#  (0.0028943895528611495, 'father_job_health')]

# %%
important_factors_full_df = pd.DataFrame (important_factors,columns=['Weight','Factor'])
important_factors_df= important_factors_full_df.head(12)

important_factors_df
# Out:
#       Weight            Factor
# 0   0.268469          Q2_score
# 1   0.170772          Q1_score
# 2   0.036353          absences
# 3   0.025376               age
# 4   0.024899            health
# 5   0.022129            go_out
# 6   0.021605          failures
# 7   0.021250  father_education
# 8   0.021216         free_time
# 9   0.020766  mother_education
# 10  0.019895   weekend_alcohol
# 11  0.018807        study_time

# %%
plt.figure(figsize=(15,15))
plt.xticks(range(len(important_factors_df['Weight']*100)), important_factors_df['Factor'])
plt.xlabel('Factor',fontsize=15)
plt.ylabel('Weights',fontsize=15)
plt.title('Important Feature',fontsize=20)
plt.bar(range(len(important_factors_df['Weight']*100)), (important_factors_df['Weight']*100)) 
plt.show()

# %%
# create highest grade student dataframe
high_df = student_data_df.loc[student_data_df.final_letter_grade != 'A+']
# create lowest score student dataframe
low_df = student_data_df.loc[student_data_df.final_letter_grade == 'F']
low_df
# Out:
#     school sex  age address family_size parents_status  mother_education  \
# 0       GP   F   18       U         GT3              A                 4
# 1       GP   F   17       U         GT3              T                 1
# 2       GP   F   15       U         LE3              T                 1
# 4       GP   F   16       U         GT3              T                 3
# 7       GP   F   17       U         GT3              A                 4
# ..     ...  ..  ...     ...         ...            ...               ...
# 640     MS   M   18       R         GT3              T                 4
# 643     MS   F   18       R         GT3              T                 4
# 644     MS   F   19       R         GT3              T                 2
# 646     MS   F   18       U         GT3              T                 1
# 647     MS   M   17       U         LE3              T                 3
#
#      father_education mother_job father_job  ... free_time go_out  \
# 0                   4    at_home    teacher  ...         3      4
# 1                   1    at_home      other  ...         3      3
# 2                   1    at_home      other  ...         3      2
# 4                   3      other      other  ...         3      2
# 7                   4      other    teacher  ...         1      4
# ..                ...        ...        ...  ...       ...    ...
# 640                 2      other      other  ...         4      3
# 643                 4    teacher    at_home  ...         4      3
# 644                 3   services      other  ...         4      2
# 646                 1      other      other  ...         1      1
# 647                 1   services   services  ...         4      5
#
#      weekday_alcohol  weekend_alcohol  health absences Q1_score Q2_score  \
# 0                  1                1       3        6        5        6
# 1                  1                1       3        4        5        5
# 2                  2                3       3       10        7        8
# 4                  1                2       5        4        6       10
# 7                  1                1       1        6        6        5
# ..               ...              ...     ...      ...      ...      ...
# 640                4                3       3        0        7        7
# 643                2                2       5        4        7        9
# 644                1                2       5        4       10       11
# 646                1                1       5        6       11       12
# 647                3                4       2        6       10       10
#
#     final_score final_letter_grade
# 0             6                  F
# 1             6                  F
# 2            10                  F
# 4            10                  F
# 7             6                  F
# ..          ...                ...
# 640           0                  F
# 643          10                  F
# 644          10                  F
# 646           9                  F
# 647          10                  F
#
# [383 rows x 34 columns]

# %%
# Q1 score level(numeric:  1 - very low to 5 - very high)
# Plot high and low performers and Q1 Scores
plt.figure(figsize=(10,10))
sns.kdeplot(high_df['Q1_score'],fill=True, color="g")
sns.kdeplot(low_df['Q1_score'], fill=True, color="r")
plt.xlabel('Q1 score')
plt.title('Q1 Score plot for high and low performing students', fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c93e24ce3ea0> in <module>
#       2 # Plot high and low performers and Q1 Scores
#       3 plt.figure(figsize=(10,10))
# ----> 4 sns.kdeplot(high_df['Q1_score'],fill=True, color="g")
#       5 sns.kdeplot(low_df['Q1_score'], fill=True, color="r")
#       6 plt.xlabel('Q1 score')
#
# ~\Anaconda\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     698                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     699     else:
# --> 700         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     701                                  gridsize, cut, clip, legend, ax,
#     702                                  cumulative=cumulative, **kwargs)
#
# ~\Anaconda\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     321     # Use the active color cycle to find the plot color
#     322     facecolor = kwargs.pop("facecolor", None)
# --> 323     line, = ax.plot(x, y, **kwargs)
#     324     color = line.get_color()
#     325     line.remove()
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     361                 "2.2", message="cycling among columns of inputs with "
#     362                 "non-matching shapes is deprecated.")
# --> 363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     364                 for j in range(max(ncx, ncy))]
#     365
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     361                 "2.2", message="cycling among columns of inputs with "
#     362                 "non-matching shapes is deprecated.")
# --> 363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     364                 for j in range(max(ncx, ncy))]
#     365
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     253         default_dict = self._getdefaults(set(), kw)
#     254         self._setdefaults(default_dict, kw)
# --> 255         seg = mlines.Line2D(x, y, **kw)
#     256         return seg
#     257
#
# ~\Anaconda\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398         # update kwargs before updating data to give the caller a
#     399         # chance to init axes (and hence unit support)
# --> 400         self.update(kwargs)
#     401         self.pickradius = pickradius
#     402         self.ind_offset = 0
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Line2D' object has no property 'fill'

# %% [markdown]
# # Linear regression on Absences and Final Score

# %%
#Simple linear regression with Final score as the dependent variable and Period one as the independent variable

X_new = student_data_df.iloc[:,29:30].values
y_new = student_data_df.iloc[:,-3].values


#X_new = X_new.reshape(-1,1)
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new,y_new,random_state = 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_new, y_train_new)

#Predicting the Test set results
predictions_new = model.predict(X_test_new)
score_new= model.score(X_test_new, y_test_new)
print(f"True output: {y_test_new[0]}")
print(f"Predicted output: {predictions_new[0]}")
print(f"Prediction Error: {predictions_new[0]-y_test_new[0]}")
print(f"Rsquare score: {score_new}")

predicted_df=pd.DataFrame({"Predicted": predictions_new, "Actual": y_test_new, "Error": predictions_new - y_test_new})[["Predicted", "Actual", "Error"]]
predicted_df
# Out:
# True output: 10
# Predicted output: 11.071640626979502
# Prediction Error: 1.0716406269795016
# Rsquare score: -0.0035150438190372224
#      Predicted  Actual     Error
# 0    11.071641      10  1.071641
# 1     9.872101       8  1.872101
# 2    11.507837      13 -1.492163
# 3    11.235214      11  0.235214
# 4    11.507837      12 -0.492163
# ..         ...     ...       ...
# 256  10.908067      11 -0.091933
# 257  11.180690      13 -1.819310
# 258  11.507837      17 -5.492163
# 259  10.635444      12 -1.364556
# 260  10.635444      11 -0.364556
#
# [261 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_train_new, y_train_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Absences (Training data)',fontsize=20)
plt.xlabel('Absences',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
#Visualizing the Testing data results
plt.figure(figsize=(10,10))
plt.scatter(X_test_new, y_test_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Absences (Testing data)',fontsize=20)
plt.xlabel('Absences',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
#Simple linear regression with Final score as the dependent variable and Period one as the independent variable

X_new = student_data_df.iloc[:,28:29].values
y_new = student_data_df.iloc[:,-4].values


#X_new = X_new.reshape(-1,1)
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new,y_new,random_state = 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_new, y_train_new)

#Predicting the Test set results
predictions_new = model.predict(X_test_new)
score_new= model.score(X_test_new, y_test_new)
print(f"True output: {y_test_new[0]}")
print(f"Predicted output: {predictions_new[0]}")
print(f"Prediction Error: {predictions_new[0]-y_test_new[0]}")
print(f"Rsquare score: {score_new}")

predicted_df=pd.DataFrame({"Predicted": predictions_new, "Actual": y_test_new, "Error": predictions_new - y_test_new})[["Predicted", "Actual", "Error"]]
predicted_df
# Out:
# True output: 9
# Predicted output: 11.07887751503541
# Prediction Error: 2.07887751503541
# Rsquare score: 0.007925702312146066
#      Predicted  Actual     Error
# 0    11.078878       9  2.078878
# 1    11.078878       8  3.078878
# 2    11.255199      14 -2.744801
# 3    11.343360      10  1.343360
# 4    11.343360      12 -0.656640
# ..         ...     ...       ...
# 256  11.078878      12 -0.921122
# 257  11.167038      11  0.167038
# 258  11.255199      17 -5.744801
# 259  11.078878      10  1.078878
# 260  11.343360      12 -0.656640
#
# [261 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_train_new, y_train_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Health (Training data)',fontsize=20)
plt.xlabel('Health',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
#Visualizing the Testing data results
plt.figure(figsize=(10,10))
plt.scatter(X_test_new, y_test_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Health (Testing data)',fontsize=20)
plt.xlabel('Health',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
# Free time after school (numeric: from 1 - very low to 5 - very high)
plt.figure(figsize=(10,10))
sns.boxplot(x='health', y='final_score',data=student_data_df,palette="Set1")
#sns.swarmplot(x='age', y='final_score',data=student_data_df, color=".25")
plt.title('Distribution Of Final Score By Health', fontsize=20)
plt.ylabel('Final score', fontsize=15)
plt.xlabel('Health', fontsize=15)
# Out:
# Text(0.5, 0, 'Health')

# %%
# going out with friends (numeric: 1 - very low to 5 - very high)
plt.figure(figsize=(15,15))
sns.boxplot(x='absences', y='final_score', data=student_data_df, orient="h", palette='Set2')
plt.title('Final Grade By Frequency of Absences', fontsize=20)
plt.ylabel('Final Score', fontsize=15)
plt.xlabel('Frequency of Absences', fontsize=15)
# Out:
# Text(0.5, 0, 'Frequency of Absences')
