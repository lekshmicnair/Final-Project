# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Reading and Cleaning Data

# %%
# Load the Math and Portuguese data
math_df = pd.read_csv("data/student-mat.csv", sep=';')
port_df = pd.read_csv("data/student-por.csv", sep=';')


math_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
port_df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
port_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
math_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Combine the data
student_data_df = pd.concat([math_df,port_df])
student_data_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# Check for any missing values
student_data_df.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
# Rename columns
student_data_df.columns = ['school','sex','age','address','family_size','parents_status','mother_education','father_education',
           'mother_job','father_job','reason','guardian','travel_time','study_time','failures','school_support',
          'family_support','paid_classes','extra_activities','nursery_school','wants_higher_edu','internet','romantic','family_relation',
          'free_time','go_out','weekday_alcohol','weekend_alcohol','health','absences','Q1_score','Q2_score','final_score']

# %%
# Create final grade column for letter grades A+:18-20 A:16-17 B:14-15 C:10-13 & F<10 
student_data_df['final_letter_grade'] = 'None'
student_data_df.loc[(student_data_df.final_score >= 18) & (student_data_df.final_score <= 20), 'final_letter_grade'] = 'A+' 
student_data_df.loc[(student_data_df.final_score >= 16) & (student_data_df.final_score <= 17), 'final_letter_grade'] = 'A'
student_data_df.loc[(student_data_df.final_score >= 14) & (student_data_df.final_score <= 15), 'final_letter_grade'] = 'B' 
student_data_df.loc[(student_data_df.final_score >= 10) & (student_data_df.final_score <= 13), 'final_letter_grade'] = 'C' 
student_data_df.loc[(student_data_df.final_score >= 0) & (student_data_df.final_score <= 10), 'final_letter_grade'] = 'F' 
student_data_df
# Out:
#     school sex  age address family_size parents_status  mother_education  \
# 0       GP   F   18       U         GT3              A                 4
# 1       GP   F   17       U         GT3              T                 1
# 2       GP   F   15       U         LE3              T                 1
# 3       GP   F   15       U         GT3              T                 4
# 4       GP   F   16       U         GT3              T                 3
# ..     ...  ..  ...     ...         ...            ...               ...
# 644     MS   F   19       R         GT3              T                 2
# 645     MS   F   18       U         LE3              T                 3
# 646     MS   F   18       U         GT3              T                 1
# 647     MS   M   17       U         LE3              T                 3
# 648     MS   M   18       R         LE3              T                 3
#
#      father_education mother_job father_job  ... free_time go_out  \
# ...

# %%
#Check for null
student_data_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Final Grade distribution and Correlation Plots

# %%
# Final grade plot
sns.set_theme(style="darkgrid")
plt.figure(figsize=(10,10))
sns.countplot(student_data_df.final_letter_grade,order=["A+","A","B","C","F"], palette='Set2')
plt.xlabel('Final Grade',fontsize=15)
plt.ylabel('Count of Students',fontsize=15)
plt.title('Final Grade Distribution',fontsize=20)

plt.savefig ('Visualizations/Final_grade.png')

# %%
#Correlation Heatmap to see the correlation between the variables
student_data_corr = student_data_df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(student_data_corr, annot=True, cmap="Purples")
plt.title('Correlation Heatmap', fontsize=20)

plt.savefig ('Visualizations/Heatmap.png')

# %% [markdown]
# # Initial Model

# %%
#Classification -Imports and Data Preprocessing

from sklearn import tree
from sklearn.preprocessing import LabelEncoder

#Classification_df= student_data_df.drop([ 'final_score','Q1_score','Q2_score'], axis=1)

Classification_df= student_data_df.drop(['final_score'], axis=1)
label = LabelEncoder()
Classification_df.final_letter_grade = label.fit_transform(Classification_df.final_letter_grade)
Classification_df
# Out:
#     school sex  age address family_size parents_status  mother_education  \
# 0       GP   F   18       U         GT3              A                 4
# 1       GP   F   17       U         GT3              T                 1
# 2       GP   F   15       U         LE3              T                 1
# 3       GP   F   15       U         GT3              T                 4
# 4       GP   F   16       U         GT3              T                 3
# ..     ...  ..  ...     ...         ...            ...               ...
# 644     MS   F   19       R         GT3              T                 2
# 645     MS   F   18       U         LE3              T                 3
# 646     MS   F   18       U         GT3              T                 1
# 647     MS   M   17       U         LE3              T                 3
# 648     MS   M   18       R         LE3              T                 3
#
#      father_education mother_job father_job  ... family_relation free_time  \
# ...

# %%
# label encode final_grade column
#label = preprocessing.LabelEncoder()
#Classification_df.final_letter_grade = label.fit_transform(Classification_df.final_letter_grade)
X = Classification_df.drop('final_letter_grade',axis=1)

y = Classification_df.final_letter_grade
print(X.shape, y.shape)
#train test split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=56)

len(list(X_train))
# Out:
# (1044, 32) (1044,)
# 32

# %%
#encode multiple columns using get_dummies
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
feature_names = X_train.columns
print(X_train.shape, X_test.shape)
# Out:
# (783, 58) (261, 58)

# %%
X_train.columns
# Out:
# Index(['age', 'mother_education', 'father_education', 'travel_time',
#        'study_time', 'failures', 'family_relation', 'free_time', 'go_out',
#        'weekday_alcohol', 'weekend_alcohol', 'health', 'absences', 'Q1_score',
#        'Q2_score', 'school_GP', 'school_MS', 'sex_F', 'sex_M', 'address_R',
#        'address_U', 'family_size_GT3', 'family_size_LE3', 'parents_status_A',
#        'parents_status_T', 'mother_job_at_home', 'mother_job_health',
#        'mother_job_other', 'mother_job_services', 'mother_job_teacher',
#        'father_job_at_home', 'father_job_health', 'father_job_other',
#        'father_job_services', 'father_job_teacher', 'reason_course',
#        'reason_home', 'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'school_support_no',
#        'school_support_yes', 'family_support_no', 'family_support_yes',
#        'paid_classes_no', 'paid_classes_yes', 'extra_activities_no',
# ...

# %%
y_train
# Out:
# 365    0
# 59     0
# 88     4
# 370    4
# 267    2
#       ..
# 624    4
# 233    3
# 259    4
# 4      3
# 89     4
# Name: final_letter_grade, Length: 783, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
rf = RandomForestClassifier(n_estimators=500)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7318007662835249

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators = 500))
sel.fit(X_train, y_train)
sel.get_support()

selected_feat= X_train.columns[(sel.get_support())]
len(selected_feat)

selected_feat

#pd.series(sel.estimator_,feature_importances_,.ravel()).hist()
# Out:
# Index(['age', 'mother_education', 'father_education', 'study_time', 'failures',
#        'free_time', 'go_out', 'weekend_alcohol', 'health', 'absences',
#        'Q1_score', 'Q2_score'],
#       dtype='object')

# %%
important_factors=sorted(zip(rf.feature_importances_, feature_names), reverse=True)
important_factors
# Out:
# [(0.26357442783598034, 'Q2_score'),
#  (0.16859632971241925, 'Q1_score'),
#  (0.035670313110610356, 'absences'),
#  (0.02507679299266765, 'health'),
#  (0.024099859071802187, 'age'),
#  (0.023988177701810085, 'failures'),
#  (0.02229283381732524, 'free_time'),
#  (0.021690918867150258, 'go_out'),
#  (0.021394300647750497, 'mother_education'),
#  (0.021275526639270206, 'father_education'),
#  (0.020061051105135196, 'weekend_alcohol'),
#  (0.018936510531443466, 'study_time'),
#  (0.017142571511984162, 'family_relation'),
#  (0.01299929169528165, 'travel_time'),
#  (0.012378667276520048, 'weekday_alcohol'),
#  (0.009697358663655281, 'paid_classes_yes'),
#  (0.009415665135929705, 'paid_classes_no'),
#  (0.008980472175328649, 'reason_course'),
#  (0.008921179111300954, 'father_job_other'),
#  (0.008557111333607306, 'mother_job_other'),
#  (0.008481306011096318, 'family_support_yes'),
#  (0.00842589244385537, 'sex_F'),
#  (0.008377363249137806, 'extra_activities_no'),
# ...

# %% [markdown]
# # Find the main factors impacting the final score and visualize its importance.

# %%
important_factors_full_df = pd.DataFrame (important_factors,columns=['Weight','Factor'])
important_factors_df= important_factors_full_df.head(10)

important_factors_df
# Out:
#      Weight            Factor
# 0  0.263574          Q2_score
# 1  0.168596          Q1_score
# 2  0.035670          absences
# 3  0.025077            health
# 4  0.024100               age
# 5  0.023988          failures
# 6  0.022293         free_time
# 7  0.021691            go_out
# 8  0.021394  mother_education
# 9  0.021276  father_education

# %%
plt.figure(figsize=(15,15))
plt.xticks(range(len(important_factors_df['Weight']*100)), important_factors_df['Factor'])
plt.xlabel('Factor',fontsize=15)
plt.ylabel('Weights',fontsize=15)
plt.title('Important Feature',fontsize=20)
plt.bar(range(len(important_factors_df['Weight']*100)), (important_factors_df['Weight']*100)) 
plt.show()

# %%
# create highest grade student dataframe
high_df = student_data_df.loc[student_data_df.final_letter_grade != 'F']
# create lowest score student dataframe
low_df = student_data_df.loc[student_data_df.final_letter_grade == 'F']

# %% [markdown]
# # Father and Mother education and students performance

# %%
# Father education level(numeric:  1 - very low to 5 - very high)
# Plot high and low performers and fathers education
plt.figure(figsize=(10,10))
sns.kdeplot(high_df['father_education'],fill=True, color="g",label="Father Education_High Performers")
sns.kdeplot(low_df['father_education'], fill=True, color="r",label="Father Education_Low Performers")
plt.xlabel('Father Education Level')
plt.title('Fathers education plot for high and low performing students', fontsize=20)
plt.legend(loc='upper left')
plt.savefig ('Visualizations/father_edu.png')

# %%
# Mother education level(numeric: 1 - very low to 5 - very high)
# Plot high and low performers and mothers education
plt.figure(figsize=(10,10))
sns.kdeplot(high_df['mother_education'],fill=True, color="g",label="Mother Education_High Performers")
sns.kdeplot(low_df['mother_education'],fill=True, color="r",label="Mother Education_Low Performers")
plt.xlabel('Mother Education Level')
plt.title('Mothers education plot for high and low performing students', fontsize=20)
plt.legend(loc='upper left')
plt.savefig ('Visualizations/mother_edu.png')

# %% [markdown]
# # Student Absence and Final Grade

# %%
# Histogram to plot absences - number of school absences (numeric: from 0 to 93)

plt.figure(figsize=(10,10))
sns.histplot(student_data_df['absences'], kde=True,  element="step", binwidth=3)
plt.xlabel('Number of Absences', fontsize=15)
plt.ylabel('Student Count', fontsize=15)
plt.title('Number of Absences vs Student count', fontsize=20)
plt.savefig ('Visualizations/absences.png')

# %%
student_absence= student_data_df.filter(['final_letter_grade','absences'], axis=1)
student_absence_groupby=student_absence.groupby(['final_letter_grade']).sum().sort_values(by='absences')
student_absence_groupby
student_absence_groupby.plot.line(figsize=(10,10))
plt.xlabel('Final Grade', fontsize=15)
plt.ylabel('Total Number of Absences', fontsize=15)
plt.title('Final Grade and Absence', fontsize=20)
plt.savefig ('Visualizations/absences_1.png')

# %% [markdown]
# # Linear regression on Period 1, Period 2 and Final Score

# %%
#Simple linear regression with Final score as the dependent variable and Period one as the independent variable

X_new = student_data_df.iloc[:,30:31].values
y_new = student_data_df.iloc[:,-2].values


#X_new = X_new.reshape(-1,1)
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new,y_new,random_state = 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_new, y_train_new)

#Predicting the Test set results
predictions_new = model.predict(X_test_new)
score_new= model.score(X_test_new, y_test_new)
print(f"True output: {y_test_new[0]}")
print(f"Predicted output: {predictions_new[0]}")
print(f"Prediction Error: {predictions_new[0]-y_test_new[0]}")
print(f"Rsquare score: {score_new}")

predicted_df=pd.DataFrame({"Predicted": predictions_new, "Actual": y_test_new, "Error": predictions_new - y_test_new})[["Predicted", "Actual", "Error"]]
predicted_df
# Out:
# True output: 11
# Predicted output: 9.06108810447205
# Prediction Error: -1.9389118955279496
# Rsquare score: 0.6312097984729492
#      Predicted  Actual     Error
# 0     9.061088      11 -1.938912
# 1     8.012380       8  0.012380
# 2    14.304630      13  1.304630
# 3    10.109796      11 -0.890204
# 4    12.207213      12  0.207213
# ..         ...     ...       ...
# 256  12.207213      11  1.207213
# 257  11.158505      14 -2.841495
# 258  17.450755      18 -0.549245
# 259  10.109796      11 -0.890204
# 260  12.207213      12  0.207213
#
# [261 rows x 3 columns]

# %%
#Visualizing the Training data results
plt.figure(figsize=(10,10))
plt.scatter(X_train_new, y_train_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Q1 Score (Training data)',fontsize=20)
plt.xlabel('Q1 Score',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
#Visualizing the Testing data results
plt.figure(figsize=(10,10))
plt.scatter(X_test_new, y_test_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Q1 Score (Testing data)',fontsize=20)
plt.xlabel('Q1 Score',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.savefig ('Visualizations/Q1_final.png')

# %%
#Simple linear regression with Final score as the dependent variable and Period2 as the independent variable

X_new = student_data_df.iloc[:,31:32].values
y_new = student_data_df.iloc[:,-2].values

#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new,y_new,random_state = 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_new, y_train_new)

#Predicting the Test set results
predictions_new = model.predict(X_test_new)
score_new= model.score(X_test_new, y_test_new)
print(f"True output: {y_test_new[0]}")
print(f"Predicted output: {predictions_new[0]}")
print(f"Prediction Error: {predictions_new[0]-y_test_new[0]}")
print(f"Rsquare score: {score_new}")

predicted_df=pd.DataFrame({"Predicted": predictions_new, "Actual": y_test_new, "Error": predictions_new - y_test_new})[["Predicted", "Actual", "Error"]]
predicted_df
# Out:
# True output: 11
# Predicted output: 10.020846736279507
# Prediction Error: -0.9791532637204927
# Rsquare score: 0.8127019969512871
#      Predicted  Actual     Error
# 0    10.020847      11 -0.979153
# 1     7.880227       8 -0.119773
# 2    13.231776      13  0.231776
# 3    11.091157      11  0.091157
# 4    12.161466      12  0.161466
# ..         ...     ...       ...
# 256  11.091157      11  0.091157
# 257  13.231776      14 -0.768224
# 258  17.513015      18 -0.486985
# 259  12.161466      11  1.161466
# 260  11.091157      12 -0.908843
#
# [261 rows x 3 columns]

# %%
#Visualizing the Training data results
plt.figure(figsize=(10,10))
plt.scatter(X_train_new, y_train_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Q2 Score (Training data)',fontsize=20)
plt.xlabel('Q2 Score',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.show()

# %%
#Visualizing the Testing data results
plt.figure(figsize=(10,10))
plt.scatter(X_test_new, y_test_new, color = 'blue')
plt.plot(X_train_new,(model.predict(X_train_new)), color ='red')
plt.title('Final score vs Q2 Score (Testing data)',fontsize=20)
plt.xlabel('Q2 Score',fontsize=15)
plt.ylabel('Final score',fontsize=15)
plt.savefig ('Visualizations/Q2_final.png')

# %% [markdown]
# # Going Out and Final Score

# %%
# going out with friends (numeric: 1 - very low to 5 - very high)
plt.figure(figsize=(10,10))
sns.boxplot(x='go_out', y='final_score', data=student_data_df, orient="h", palette='Set2')
plt.title('Final Grade By Frequency of Going Out', fontsize=20)
plt.ylabel('Final Score', fontsize=15)
plt.xlabel('Frequency of Going Out', fontsize=15)
plt.savefig ('Visualizations/going_out.png')

# %% [markdown]
# # Age and Final Score

# %%
# Free time after school (numeric: from 1 - very low to 5 - very high)
plt.figure(figsize=(10,10))
sns.boxplot(x='age', y='final_score',data=student_data_df,palette="Set1")
#sns.swarmplot(x='age', y='final_score',data=student_data_df, color=".25")
plt.title('Distribution Of Final Score By Age', fontsize=20)
plt.ylabel('Final score', fontsize=15)
plt.xlabel('Age', fontsize=15)
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# # Urban or Rural?

# %%
# Address: urban vs. rural 
student_data_df.address = student_data_df.address.map({'U':'Urban', 'R':'Rural'})

plt.figure(figsize=(10,10))
sns.countplot(student_data_df.address, facecolor=(0, 0, 0, 0),linewidth=5,edgecolor=sns.color_palette("dark", 2))                 
plt.title('Students Count in Urban and Rural Area', fontsize=20)
plt.xlabel('Address Type', fontsize=15)
plt.ylabel('Number Of Students', fontsize=15)
plt.savefig ('Visualizations/urban_rural.png')

# %%
#Plot final grade by address area
index = ['A+','A','B','C','F']
student_address = pd.crosstab(index=student_data_df.final_letter_grade, columns=student_data_df.address)
student_address
percentage_student_address = student_address.apply(lambda col: col/col.sum()).reindex(index)
percentage_student_address.plot.bar(colormap="Paired", fontsize=15, figsize=(10,10))
plt.title('Final Grade By Address Area', fontsize=20)
plt.ylabel('Percentage of Students', fontsize=15)
plt.xlabel('Final Grade', fontsize=15)
plt.savefig ('Visualizations/urban_rural_grades.png')

# %% [markdown]
# # Desire for higher education

# %%
# Desire for higher education and study time by age 
#studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)

plt.figure(figsize=(10,10))
sns.violinplot(x='age', y='study_time', data=student_data_df, palette="Set2", hue='wants_higher_edu',ylim=(1,6))
plt.title('Distribution Of Study Time By Age & Desire For Higher Education', fontsize=20)
plt.ylabel('Study Time', fontsize=15)
plt.xlabel('Age', fontsize=15)

plt.savefig ('Visualizations/desire_he.png')

# %%
#Desire for higher education and final score
wants_high_edu = pd.crosstab(index=student_data_df.final_letter_grade, columns=student_data_df.wants_higher_edu)
percentage_high_edu = wants_high_edu.apply(lambda col: col/col.sum()).reindex(index)
percentage_high_edu.plot.bar(colormap="Set1", figsize=(10,10), fontsize=15)
plt.title('Final Grade By Desire For Higher Education', fontsize=20)
plt.xlabel('Final Grade', fontsize=15)
plt.ylabel('Percentage of Students', fontsize=15)
plt.savefig ('Visualizations/desire_he_grade.png')

# %% [markdown]
# # Alcohol Consumption

# %%
# Weekday Alcohol Consumption (numeric: from 1 - very low to 5 - very high) kde plot 
plt.figure(figsize=(10,10))
student_sorted_df=student_data_df.sort_values(by='final_score')
sns.kdeplot(student_sorted_df['weekday_alcohol'],hue=student_sorted_df["final_letter_grade"])
plt.xlabel('Alcohol Consumption Level')
plt.title('Weekday Alcohol Consumption and Student Performace', fontsize=20)

plt.savefig ('Visualizations/alc_consumption.png')

# %%
# Weekend Alcohol Consumption (numeric: from 1 - very low to 5 - very high) bar plot 
Weekend_alcohol = pd.crosstab(index=student_sorted_df.final_letter_grade, columns=student_sorted_df.weekend_alcohol)
Percentage_weekend_alcohol = Weekend_alcohol.apply(lambda col: col/col.sum()).reindex(index)
Percentage_weekend_alcohol.plot.bar(colormap="Set1", fontsize=15, figsize=(10,10))
plt.title('Final Grade By Weekend Alcohol Consumption', fontsize=20)
plt.ylabel('Percentage of Students', fontsize=15)
plt.xlabel('Final Grade', fontsize=15)
plt.savefig ('Visualizations/weekend_alcohol_grade.png')
